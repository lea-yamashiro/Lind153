# %%
# Install packages
# !pip install -r requirements.txt >/dev/null
# !pip install eep153_tools >/dev/null
# !pip install gnupg 
# !pip install gspread_pandas >/dev/null

# Import libraries
import numpy as np
import pandas as pd
import warnings
from  scipy.optimize import linprog as lp
import plotly.express as px
from eep153_tools.sheets import read_sheets
import fooddatacentral as fdc


# API Key
apikey = "Y7y8evhwYYL589qVEZzdHBCyKGeBkNdDWQfnWyIV"
# Out:
# Requirement already satisfied: gnupg in /srv/conda/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: psutil>=1.2.1 in /srv/conda/lib/python3.9/site-packages (from gnupg) (5.9.8)

# %% [markdown]
# ## [A] Description of Population of Interest

# %% [markdown]
# Our group is interested in the comparison of the minimum cost diets of the inhabitants of **San-Francisco** and **Bakersfield**, two cities chosen based on their differences in cost-of-living, population density, and locale classification (urban vs agricultural, respectively).

# %% [markdown]
# ## [A] Dietary Reference Intakes

# %% [markdown]
# A function that takes as arguments the characteristics of a given person (age, sex) and returns a Pandas.series of Dietary Reference Intakes (DRIs) or "Recommended Daily Allowances" (RDAs) of a variety of nutrients appropriate for the population of interest

# %%
# Read diet minimum data
diet_min = pd.read_csv("Spreadsheets/diet_min.csv",index_col=0)
diet_min
# Out:
#                                Source   C 1-3   F 4-8   M 4-8  F 9-13  M 9-13  \
# Nutrition
# Energy                            ---  1000.0  1200.0  1400.0  1600.0  1800.0
# Protein                           RDA    13.0    19.0    19.0    34.0    34.0
# Fiber, total dietary              ---    14.0    16.8    19.6    22.4    25.2
# Folate, DFE                       RDA   150.0   200.0   200.0   300.0   300.0
# Calcium, Ca                       RDA   700.0  1000.0  1000.0  1300.0  1300.0
# Carbohydrate, by difference       RDA   130.0   130.0   130.0   130.0   130.0
# Iron, Fe                          RDA     7.0    10.0    10.0     8.0     8.0
# Magnesium, Mg                     RDA    80.0   130.0   130.0   240.0   240.0
# Niacin                            RDA     6.0     8.0     8.0    12.0    12.0
# Phosphorus, P                     RDA   460.0   500.0   500.0  1250.0  1250.0
# Potassium, K                       AI  3000.0  3800.0  3800.0  4500.0  4500.0
# Riboflavin                        RDA     0.5     0.6     0.6     0.9     0.9
# Thiamin                           RDA     0.5     0.6     0.6     0.9     0.9
# Vitamin A, RAE                    RDA   300.0   400.0   400.0   600.0   600.0
# Vitamin B-12                      RDA     0.9     1.2     1.2     1.8     1.8
# Vitamin B-6                       RDA     0.5     0.6     0.6     1.0     1.0
# Vitamin C, total ascorbic acid    RDA    15.0    25.0    25.0    45.0    45.0
# Vitamin E (alpha-tocopherol)      RDA     6.0     7.0     7.0    11.0    11.0
# Vitamin K (phylloquinone)          AI    30.0    55.0    55.0    60.0    60.0
# Zinc, Zn                          RDA     3.0     5.0     5.0     8.0     8.0
#
#                                 F 14-18  M 14-18  F 19-30  M 19-30  F 31-50  \
# Nutrition
# Energy                           1800.0   2200.0   2000.0   2400.0   1800.0
# Protein                            46.0     52.0     46.0     56.0     46.0
# Fiber, total dietary               25.2     30.8     28.0     33.6     25.2
# Folate, DFE                       400.0    400.0    400.0    400.0    400.0
# Calcium, Ca                      1300.0   1300.0   1000.0   1000.0   1000.0
# Carbohydrate, by difference       130.0    130.0    130.0    130.0    130.0
# Iron, Fe                           15.0     11.0     18.0      8.0     18.0
# Magnesium, Mg                     360.0    410.0    310.0    400.0    320.0
# Niacin                             14.0     16.0     14.0     16.0     14.0
# Phosphorus, P                    1250.0   1250.0    700.0    700.0    700.0
# Potassium, K                     4700.0   4700.0   4700.0   4700.0   4700.0
# Riboflavin                          1.0      1.3      1.1      1.3      1.1
# Thiamin                             1.0      1.2      1.1      1.2      1.1
# Vitamin A, RAE                    700.0    900.0    700.0    900.0    700.0
# Vitamin B-12                        2.4      2.4      2.4      2.4      2.4
# Vitamin B-6                         1.2      1.3      1.3      1.3      1.3
# Vitamin C, total ascorbic acid     65.0     75.0     75.0     90.0     75.0
# Vitamin E (alpha-tocopherol)       15.0     15.0     15.0     15.0     15.0
# Vitamin K (phylloquinone)          75.0     75.0     90.0    120.0     90.0
# Zinc, Zn                            9.0     11.0      8.0     11.0      8.0
#
#                                 M 31-50   F 51+   M 51+
# Nutrition
# Energy                           2200.0  1600.0  2000.0
# Protein                            56.0    46.0    56.0
# Fiber, total dietary               30.8    22.4    28.0
# Folate, DFE                       400.0   400.0   400.0
# Calcium, Ca                      1000.0  1200.0  1000.0
# Carbohydrate, by difference       130.0   130.0   130.0
# Iron, Fe                            8.0     8.0     8.0
# Magnesium, Mg                     420.0   320.0   420.0
# Niacin                             16.0    14.0    16.0
# Phosphorus, P                     700.0   700.0   700.0
# Potassium, K                     4700.0  4700.0  4700.0
# Riboflavin                          1.3     1.1     1.3
# Thiamin                             1.2     1.1     1.2
# Vitamin A, RAE                    900.0   700.0   900.0
# Vitamin B-12                        2.4     2.4     2.4
# Vitamin B-6                         1.3     1.5     1.7
# Vitamin C, total ascorbic acid     90.0    75.0    90.0
# Vitamin E (alpha-tocopherol)       15.0    15.0    15.0
# Vitamin K (phylloquinone)         120.0    90.0   120.0
# Zinc, Zn                           11.0     8.0    11.0

# %%
# Read diet maximum data
diet_max = pd.read_csv("Spreadsheets/diet_max.csv",index_col=0)
diet_max
# Out:
#            Source  C 1-3  F 4-8  M 4-8  F 9-13  M 9-13  F 14-18  M 14-18  \
# Nutrition
# Sodium, Na     UL   1500   1900   1900    2200    2200     2300     2300
# Energy        NaN   2500   2500   2500    2800    3000     3100     3100
#
#             F 19-30  M 19-30  F 31-50  M 31-50  F 51+  M 51+
# Nutrition
# Sodium, Na     2300     2300     2300     2300   2300   2300
# Energy         3100     3100     3100     3100   3100   3100

# %%
def dietary_ref_intake(age,sex,df):
    """Takes in age and sex, and returns the dietary reference intake for the chosen population"""

    if age <= 3:
        col = 'C 1-3'
    age_ranges = [(4,8),(9,13),(14,18),(19,30),(31,50),(50,100)]
    for age_range in age_ranges:
        if age >= age_range[0] and age <= age_range[1]:
            col = sex + ' ' + str(age_range[0]) + '-' + str(age_range[1])
    return pd.Series(df[col])

# %%
# Example of minimum dietary requirements for a male aged 22
dietary_ref_intake(age=22,sex='M',df=diet_min)
# Out:
# Nutrition
# Energy                            2400.0
# Protein                             56.0
# Fiber, total dietary                33.6
# Folate, DFE                        400.0
# Calcium, Ca                       1000.0
# Carbohydrate, by difference        130.0
# Iron, Fe                             8.0
# Magnesium, Mg                      400.0
# Niacin                              16.0
# Phosphorus, P                      700.0
# Potassium, K                      4700.0
# Riboflavin                           1.3
# Thiamin                              1.2
# Vitamin A, RAE                     900.0
# Vitamin B-12                         2.4
# Vitamin B-6                          1.3
# Vitamin C, total ascorbic acid      90.0
# Vitamin E (alpha-tocopherol)        15.0
# Vitamin K (phylloquinone)          120.0
# Zinc, Zn                            11.0
# Name: M 19-30, dtype: float64

# %%
# Example of maximum dietary requirements for a male aged 22
dietary_ref_intake(age=22,sex='M',df=diet_max)
# Out:
# Nutrition
# Sodium, Na    2300
# Energy        3100
# Name: M 19-30, dtype: int64

# %% [markdown]
# ## [A] Data on prices for different foods

# %% [markdown]
# We constructed a google spreadsheet of the prices of approximately 28 ~ 29 different food products chosen from 2 different methods:
#
# * **US Consumer-Expenditure Survey Top-Results**: The first bin of foods were chosen as the most popular products per each main food groups (i.e. vegetables, fruits, meats, dairies) as concluded from the US Consumer-Expenditure Survey. This represents the baseline foods we wanted to establish to compare the two cities within our project.  Here is a link to what we looked at: https://www.ers.usda.gov/data-products/ag-and-food-statistics-charting-the-essentials/food-availability-and-consumption/
# * **Insta-Cart 2021 Most Popular Groceries by City**: We then compiled the most popular groceries per region by searching by city through Instacart's 2021 Delivered project: https://www.instacart.com/2021-delivered/

# %% [markdown]
# ### Identifying and Uploading FDC

# %%
df = pd.read_csv('Spreadsheets/grocery_names.csv')
df['Food'] = df['Item']
df
# Out:
#                       Item                    Food
# 0            Hass Avocado            Hass Avocado
# 1                     Tofu                    Tofu
# 2            Lacinato Kale           Lacinato Kale
# 3                 Oat Milk                Oat Milk
# 4        Flat Leaf Parsley       Flat Leaf Parsley
# 5          Maradol Papayas         Maradol Papayas
# 6            Gemelli Pasta           Gemelli Pasta
# 7            Roma Tomatoes           Roma Tomatoes
# 8          Serrano Peppers         Serrano Peppers
# 9                 Cilantro                Cilantro
# 10          Corn Tortillas          Corn Tortillas
# 11                 Chorizo                 Chorizo
# 12          Pressed Juices          Pressed Juices
# 13                 Arugula                 Arugula
# 14                  Apples                  Apples
# 15                 Oranges                 Oranges
# 16                 Bananas                 Bananas
# 17                Potatoes                Potatoes
# 18     Tomatoes (Vine Red)     Tomatoes (Vine Red)
# 19                    Milk                    Milk
# 20                  Cheese                  Cheese
# 21  Chips (Lay's Original)  Chips (Lay's Original)
# 22                   Bread                   Bread
# 23                   Flour                   Flour
# 24                 Chicken                 Chicken
# 25            Ground Beef             Ground Beef
# 26                    Eggs                    Eggs
# 27                  Onions                  Onions

# %%
# (IGNORE FOR PROJECT) idea for further automation/ease here: if you inputted a dataframe with your 
# chosen foods having already designated for the "foodCategory" column, that way you could have some 
# kind of if/else statement that filters to find the FIRST index row with that DESIRED (and more accurate) 
# food category as the value in that column of the FDC dataframe. This way you could weed out rando ones, 
# like when we get "Avocado Chunks" as the SECOND result in a search for Hass Avocadoes. 

import fooddatacentral as fdc
import warnings

apikey = 'Y7y8evhwYYL589qVEZzdHBCyKGeBkNdDWQfnWyIV'

def find_FDC_index(API_key, food_list, num_rows): 
    
    fdc_index_results = pd.DataFrame(columns=['Food', 'fdcId', 'description', 'foodCategory'])
    
    for food in food_list: 
        df_food = fdc.search(apikey, food)
        df_food_reduced = df_food[['fdcId', 'description', 'foodCategory']]
        df_food_reduced['Food'] = str(food)
        df_food_4_results = df_food_reduced.iloc[:num_rows]
        fdc_index_results = fdc_index_results.append(df_food_4_results, ignore_index = True)
        
    return fdc_index_results

# %%
get_fdcIds = find_FDC_index(apikey, df['Item'], 1)
get_fdcIds
# Out:
# /tmp/ipykernel_462/3561763109.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food_reduced['Food'] = str(food)
#                       Food    fdcId  \
# 0            Hass Avocado   2609822
# 1                     Tofu  2294522
# 2            Lacinato Kale  2495872
# 3                 Oat Milk  2257046
# 4        Flat Leaf Parsley   170416
# 5          Maradol Papayas   169926
# 6            Gemelli Pasta  2618997
# 7            Roma Tomatoes  1608947
# 8          Serrano Peppers  2390015
# 9                 Cilantro   399147
# 10          Corn Tortillas  1850647
# 11                 Chorizo  2341591
# 12          Pressed Juices  2341550
# 13                 Arugula  2630019
# 14                  Apples  1545857
# 15                 Oranges   578523
# 16                 Bananas   173945
# 17                Potatoes   576920
# 18     Tomatoes (Vine Red)   170050
# 19                    Milk  1909132
# 20                  Cheese  2679762
# 21  Chips (Lay's Original)  1635045
# 22                   Bread  2431121
# 23                   Flour  2671058
# 24                 Chicken  2090362
# 25            Ground Beef   1942314
# 26                    Eggs  1663044
# 27                  Onions  2345315
#
#                                           description  \
# 0                                 HASS AVOCADOS, HASS
# 1                                                TOFU
# 2   LACINATO TUSCAN KALE CUT SUPER GREENS, LACINAT...
# 3          Oat milk, unsweetened, plain, refrigerated
# 4                                      Parsley, fresh
# 5                                        Papayas, raw
# 6    GEMELLI & SPINACH PASTA SALAD, GEMELLI & SPINACH
# 7                                       ROMA TOMATOES
# 8                                     SERRANO PEPPERS
# 9                                            CILANTRO
# 10                                     CORN TORTILLAS
# 11                                            Chorizo
# 12                             Duck, pressed, Chinese
# 13                                            ARUGULA
# 14                                             APPLES
# 15                                            ORANGES
# 16              Bananas, dehydrated, or banana powder
# 17                                           POTATOES
# 18                        Tomatoes, red, ripe, cooked
# 19                                               MILK
# 20                                             CHEESE
# 21       LAY'S, WAVY POTATO CHIPS, ORIGINAL, ORIGINAL
# 22                                              BREAD
# 23                                              FLOUR
# 24                                            CHICKEN
# 25                                        GROUND BEEF
# 26                                               EGGS
# 27                                        Onions, raw
#
#                            foodCategory
# 0       Pre-Packaged Fruit & Vegetables
# 1                           Other Meats
# 2       Pre-Packaged Fruit & Vegetables
# 3                             Beverages
# 4     Vegetables and Vegetable Products
# 5               Fruits and Fruit Juices
# 6                           Deli Salads
# 7       Pre-Packaged Fruit & Vegetables
# 8   Pickles, Olives, Peppers & Relishes
# 9                        Herbs & Spices
# 10                 Mexican Dinner Mixes
# 11                             Sausages
# 12          Turkey, duck, other poultry
# 13      Pre-Packaged Fruit & Vegetables
# 14      Pre-Packaged Fruit & Vegetables
# 15      Pre-Packaged Fruit & Vegetables
# 16              Fruits and Fruit Juices
# 17      Pre-Packaged Fruit & Vegetables
# 18    Vegetables and Vegetable Products
# 19                                 Milk
# 20                               Cheese
# 21             Chips, Pretzels & Snacks
# 22                   Cookies & Biscuits
# 23                   Flours & Corn Meal
# 24            Poultry, Chicken & Turkey
# 25                          Other Meats
# 26               Eggs & Egg Substitutes
# 27                               Onions

# %%
fdcId_array = get_fdcIds['fdcId']
print(fdcId_array)
# Out:
# 0     2609822
# 1     2294522
# 2     2495872
# 3     2257046
# 4      170416
# 5      169926
# 6     2618997
# 7     1608947
# 8     2390015
# 9      399147
# 10    1850647
# 11    2341591
# 12    2341550
# 13    2630019
# 14    1545857
# 15     578523
# 16     173945
# 17     576920
# 18     170050
# 19    1909132
# 20    2679762
# 21    1635045
# 22    2431121
# 23    2671058
# 24    2090362
# 25    1942314
# 26    1663044
# 27    2345315
# Name: fdcId, dtype: object

# %%
file_path = "Spreadsheets/fdc_ids.csv"

# Save the DataFrame to a CSV file
fdcId_array.to_csv(file_path, index=False)

# %% [markdown]
# ### Notes from FDC ID DataFrame:
# - for Gemelli Pasta, pd.iloc[0] will get fdcId = 2618997, change to fdcId = 1124597
# - "pressed Juices" are fucked up, need to do that search separately
# - "Bread" is outputting some cookies and biscuits shit, replace with fdcId = 1913550

# %%
gemelli_fdcID = 1124597
bread_fdcID = 1913550
pressedjuice_fdcID = 2095092

# %%
# getting FDC Codes

import fooddatacentral as fdc
import warnings
df1 = fdc.search(apikey, 'Cold Pressed Juice')
df1.head(5)
# Out:
#      fdcId         description dataType       gtinUpc publishedDate  \
# 0  2075597  COLD PRESSED JUICE  Branded  852043003810    2021-10-28
# 1   522238  COLD PRESSED JUICE  Branded  857134006749    2019-04-01
# 2  1919466  COLD PRESSED JUICE  Branded  653341767899    2021-07-29
# 3  2095092  COLD PRESSED JUICE  Branded  813377021864    2021-10-28
# 4  1889790  COLD PRESSED JUICE  Branded  854649005960    2021-07-29
#
#                        brandOwner               brandName  \
# 0  The Hain Celestial Group, Inc.               BLUEPRINT
# 1              WHOLE FOODS MARKET                     NaN
# 2      A.M.S. Manufacturing, Inc.              JONI JUICE
# 3                    Urban Remedy  365 WHOLE FOODS MARKET
# 4                   Pressery LLC       WHOLE FOODS MARKET
#
#                                          ingredients  marketCountry  \
# 0  JUICE FROM: ORGANIC ROMAINE, ORGANIC APPLE, OR...  United States
# 1       ORANGE, TURMERIC, CURRY POWDER, BALCK PEPPER  United States
# 2  APPLE, KALE, MINT, LEMON, GINGER, SPIRULINA, M...  United States
# 3         PINEAPPLE JUICE, LIME JUICE, GINGER JUICE.  United States
# 4                     CARROTS, BEETS, LEMON, GINGER.  United States
#
#                                       foodCategory  ... foodMeasures  \
# 0  Fruit & Vegetable Juice, Nectars & Fruit Drinks  ...           []
# 1  Fruit & Vegetable Juice, Nectars & Fruit Drinks  ...           []
# 2  Fruit & Vegetable Juice, Nectars & Fruit Drinks  ...           []
# 3  Fruit & Vegetable Juice, Nectars & Fruit Drinks  ...           []
# 4  Fruit & Vegetable Juice, Nectars & Fruit Drinks  ...           []
#
#   foodAttributes foodAttributeTypes foodVersionIds  householdServingFullText  \
# 0             []                 []             []                       NaN
# 1             []                 []             []                     2 OZA
# 2             []                 []             []                       NaN
# 3             []                 []             []                       NaN
# 4             []                 []             []                       NaN
#
#   shortDescription commonNames  additionalDescriptions ndbNumber subbrandName
# 0              NaN         NaN                     NaN       NaN          NaN
# 1              NaN         NaN                     NaN       NaN          NaN
# 2              NaN         NaN                     NaN       NaN          NaN
# 3              NaN         NaN                     NaN       NaN          NaN
# 4              NaN         NaN                     NaN       NaN          NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### DataFrames from Google Sheets

# %%
def read_sheet(city):
    df = pd.read_csv("Spreadsheets/" + city + ".csv")
    df = df.iloc[:,:5].dropna(subset=['FDC'])
    df = df.reset_index(drop=True)
    df['FDC'] = df['FDC'].astype(int)
    return df
    return df

# %%
sf = read_sheet("San_Francisco")
bakersfield = read_sheet("Bakersfield")

sf
# Out:
#                       Item  Quantity   Units  Price      FDC
# 0            Hass Avocado        6.0      oz   2.00  2609822
# 1                     Tofu      14.0      oz   3.49  2294522
# 2            Lacinato Kale       1.0      lb   3.49  2495872
# 3                 Oat Milk      64.0      oz   5.99  2257046
# 4        Flat Leaf Parsley       2.0      oz   1.79   170416
# 5          Maradol Papayas       1.0      lb   3.99   169926
# 6            Gemelli Pasta       7.0      oz   2.79  1124597
# 7            Roma Tomatoes       1.0      lb   3.49  1608947
# 8          Serrano Peppers       0.1      lb   0.75  2390015
# 9                 Cilantro       2.8      oz   1.69   399147
# 10          Corn Tortillas      16.0      oz   2.99  1850647
# 11                 Chorizo       9.0      oz   2.49  2341591
# 12          Pressed Juices      12.0   fl oz   5.99  2095092
# 13                 Arugula       5.0      oz   3.99  2630019
# 14                  Apples       3.0      lb   4.99  1545857
# 15                 Oranges       3.0      lb   6.99   578523
# 16                 Bananas       1.0      lb   0.99   173945
# 17                Potatoes       5.0      lb   5.99   576920
# 18     Tomatoes (Vine Red)       1.0      lb   3.99   170050
# 19                    Milk       1.0  gallon   5.99  1909132
# 20                  Cheese       8.0      oz   4.49  2679762
# 21  Chips (Lay's Original)       8.0      oz   4.79  1635045
# 22                   Bread      20.0      oz   5.29  1913550
# 23                   Flour       5.0      lb   4.99  2671058
# 24                 Chicken       2.0      lb  13.98  2090362
# 25            Ground Beef        3.0      lb  20.97  1942314
# 26                    Eggs       1.5   dozen   7.99  1663044
# 27                  Onions       3.0      lb   3.99  2345315

# %% [markdown]
# ### Unit Conversion

# %%
def convert(df):
    # Convert food quantities to FDC units
    df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

    # Now may want to filter df by time or place--need to get a unique set of food names.
    df['FDC Price'] = df['Price']/df['FDC Quantity']

    df.dropna(how='any') # Drop food with any missing data

    # To use minimum price observed
    Prices = df.groupby('Item',sort=False)['FDC Price'].min()

    return Prices

# %%
sf_price = convert(sf)
bakersfield_price = convert(bakersfield)
# Out:
# ---------------------------------------------------------------------------
# DimensionalityError                       Traceback (most recent call last)
# File /srv/conda/lib/python3.9/site-packages/fooddatacentral/fooddatacentral.py:119, in units(q, u, ureg)
#     118 try:
# --> 119     return x.to(ureg.hectogram)
#     120 except DimensionalityError:
#
# File /srv/conda/lib/python3.9/site-packages/pint/quantity.py:660, in Quantity.to(self, other, *contexts, **ctx_kwargs)
#     658 other = to_units_container(other, self._REGISTRY)
# --> 660 magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     662 return self.__class__(magnitude, other)
#
# File /srv/conda/lib/python3.9/site-packages/pint/quantity.py:609, in Quantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     607         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 609 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:947, in BaseRegistry.convert(self, value, src, dst, inplace)
#     945     return value
# --> 947 return self._convert(value, src, dst, inplace)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:1830, in ContextRegistry._convert(self, value, src, dst, inplace)
#    1828         value, src = src._magnitude, src._units
# -> 1830 return super()._convert(value, src, dst, inplace)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:1433, in NonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#    1432 if not (src_offset_unit or dst_offset_unit):
# -> 1433     return super()._convert(value, src, dst, inplace)
#    1435 src_dim = self._get_dimensionality(src)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:980, in BaseRegistry._convert(self, value, src, dst, inplace, check_dimensionality)
#     979     if src_dim != dst_dim:
# --> 980         raise DimensionalityError(src, dst, src_dim, dst_dim)
#     982 # Here src and dst have only multiplicative units left. Thus we can
#     983 # convert with a factor.
#
# DimensionalityError: Cannot convert from 'femtoliter * ounce' ([length] ** 3 * [mass]) to 'hectogram' ([mass])
#
# During handling of the above exception, another exception occurred:
#
# DimensionalityError                       Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 sf_price = convert(sf)
#       2 bakersfield_price = convert(bakersfield)
#
# Cell In[94], line 3, in convert(df)
#       1 def convert(df):
#       2     # Convert food quantities to FDC units
# ----> 3     df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#       5     # Now may want to filter df by time or place--need to get a unique set of food names.
#       6     df['FDC Price'] = df['Price']/df['FDC Quantity']
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/frame.py:8740, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8729 from pandas.core.apply import frame_apply
#    8731 op = frame_apply(
#    8732     self,
#    8733     func=func,
#    (...)
#    8738     kwargs=kwargs,
#    8739 )
# -> 8740 return op.apply()
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/apply.py:812, in FrameApply.apply_standard(self)
#     811 def apply_standard(self):
# --> 812     results, res_index = self.apply_series_generator()
#     814     # wrap results
#     815     return self.wrap_results(results, res_index)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/apply.py:828, in FrameApply.apply_series_generator(self)
#     825 with option_context("mode.chained_assignment", None):
#     826     for i, v in enumerate(series_gen):
#     827         # ignore SettingWithCopy here in case the user mutates
# --> 828         results[i] = self.f(v)
#     829         if isinstance(results[i], ABCSeries):
#     830             # If we have a view on v, we need to make a copy because
#     831             #  series_generator will swap out the underlying data
#     832             results[i] = results[i].copy(deep=False)
#
# Cell In[94], line 3, in convert.<locals>.<lambda>(x)
#       1 def convert(df):
#       2     # Convert food quantities to FDC units
# ----> 3     df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#       5     # Now may want to filter df by time or place--need to get a unique set of food names.
#       6     df['FDC Price'] = df['Price']/df['FDC Quantity']
#
# File /srv/conda/lib/python3.9/site-packages/fooddatacentral/fooddatacentral.py:121, in units(q, u, ureg)
#     119     return x.to(ureg.hectogram)
#     120 except DimensionalityError:
# --> 121     return x.to(ureg.deciliter)
#
# File /srv/conda/lib/python3.9/site-packages/pint/quantity.py:660, in Quantity.to(self, other, *contexts, **ctx_kwargs)
#     643 """Return Quantity rescaled to different units.
#     644
#     645 Parameters
#    (...)
#     656 pint.Quantity
#     657 """
#     658 other = to_units_container(other, self._REGISTRY)
# --> 660 magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     662 return self.__class__(magnitude, other)
#
# File /srv/conda/lib/python3.9/site-packages/pint/quantity.py:609, in Quantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     606     with self._REGISTRY.context(*contexts, **ctx_kwargs):
#     607         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 609 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:947, in BaseRegistry.convert(self, value, src, dst, inplace)
#     944 if src == dst:
#     945     return value
# --> 947 return self._convert(value, src, dst, inplace)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:1830, in ContextRegistry._convert(self, value, src, dst, inplace)
#    1826             src = self._active_ctx.transform(a, b, self, src)
#    1828         value, src = src._magnitude, src._units
# -> 1830 return super()._convert(value, src, dst, inplace)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:1433, in NonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#    1428     raise DimensionalityError(
#    1429         src, dst, extra_msg=f" - In destination units, {ex}"
#    1430     )
#    1432 if not (src_offset_unit or dst_offset_unit):
# -> 1433     return super()._convert(value, src, dst, inplace)
#    1435 src_dim = self._get_dimensionality(src)
#    1436 dst_dim = self._get_dimensionality(dst)
#
# File /srv/conda/lib/python3.9/site-packages/pint/registry.py:980, in BaseRegistry._convert(self, value, src, dst, inplace, check_dimensionality)
#     977     # If the source and destination dimensionality are different,
#     978     # then the conversion cannot be performed.
#     979     if src_dim != dst_dim:
# --> 980         raise DimensionalityError(src, dst, src_dim, dst_dim)
#     982 # Here src and dst have only multiplicative units left. Thus we can
#     983 # convert with a factor.
#     984 factor, _ = self._get_root_units(src / dst)
#
# DimensionalityError: Cannot convert from 'femtoliter * ounce' ([length] ** 3 * [mass]) to 'deciliter' ([length] ** 3)

# %% [markdown]
# # [A] Nutritional content of different foods

# %% [markdown]
# Now, using the FDC ID, we look up the nutritional content of the grocery lists we've created to construct DataFrames containing the results

# %%
def content(city):
    df = read_sheet(city)
    D = {}
    count = 0
    for item in  df.Item.tolist():
        try:
            FDC = df.loc[df.Item==item,:].FDC[count]
            count+=1
            D[item] = fdc.nutrients(apikey,FDC).Quantity
        except AttributeError: 
            warnings.warn("Couldn't find FDC Code %s for item %s." % (item,FDC))
    return pd.DataFrame(D,dtype=float)

# %%
sf_content = content(sf)
bakersfield_content = content(bakersfield)

sf_content
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 sf_content = content(sf)
#       2 bakersfield_content = content(bakersfield)
#       4 sf_content
#
# Cell In[97], line 2, in content(city)
#       1 def content(city):
# ----> 2     df = read_sheet(city)
#       3     D = {}
#       4     count = 0
#
# Cell In[92], line 2, in read_sheet(city)
#       1 def read_sheet(city):
# ----> 2     df = pd.read_csv("Spreadsheets/" + city + ".csv")
#       3     df = df.iloc[:,:5].dropna(subset=['FDC'])
#       4     df = df.reset_index(drop=True)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/ops/common.py:69, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      65             return NotImplemented
#      67 other = item_from_zerodim(other)
# ---> 69 return method(self, other)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/arraylike.py:96, in OpsMixin.__radd__(self, other)
#      94 @unpack_zerodim_and_defer("__radd__")
#      95 def __radd__(self, other):
# ---> 96     return self._arith_method(other, roperator.radd)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/frame.py:6866, in DataFrame._arith_method(self, other, op)
#    6862 other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6864 self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
# -> 6866 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    6867 return self._construct_result(new_data)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/frame.py:6893, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    6890 if not is_list_like(right):
#    6891     # i.e. scalar, faster than checking np.ndim(right) == 0
#    6892     with np.errstate(all="ignore"):
# -> 6893         bm = self._mgr.apply(array_op, right=right)
#    6894     return type(self)(bm)
#    6896 elif isinstance(right, DataFrame):
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py:325, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     323 try:
#     324     if callable(f):
# --> 325         applied = b.apply(f, **kwargs)
#     326     else:
#     327         applied = getattr(b, f)(**kwargs)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/internals/blocks.py:381, in Block.apply(self, func, **kwargs)
#     376 """
#     377 apply the function to my values; return a block if we are not
#     378 one
#     379 """
#     380 with np.errstate(all="ignore"):
# --> 381     result = func(self.values, **kwargs)
#     383 return self._split_op_result(result)
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:224, in arithmetic_op(left, right, op)
#     219 else:
#     220     # TODO we should handle EAs consistently and move this check before the if/else
#     221     # (https://github.com/pandas-dev/pandas/issues/41165)
#     222     _bool_arith_check(op, left, right)
# --> 224     res_values = _na_arithmetic_op(left, right, op)
#     226 return res_values
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:166, in _na_arithmetic_op(left, right, op, is_cmp)
#     163     func = partial(expressions.evaluate, op)
#     165 try:
# --> 166     result = func(left, right)
#     167 except TypeError:
#     168     if is_object_dtype(left) or is_object_dtype(right) and not is_cmp:
#     169         # For object dtype, fallback to a masked operation (only operating
#     170         #  on the non-missing values)
#     171         # Don't do this for comparisons, as that will handle complex numbers
#     172         #  incorrectly, see GH#32047
#
# File /srv/conda/lib/python3.9/site-packages/pandas/core/roperator.py:9, in radd(left, right)
#       8 def radd(left, right):
# ----> 9     return right + left
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U13'), dtype('float64')) -> None

# %%
sf_content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 sf_content
#
# NameError: name 'sf_content' is not defined

# %% [markdown]
# ## [A] Solution

# %% [markdown]
# Here we create a single function `solve_subsistence_problem`.  By
# isolating the logic of constructing and solving the subsistence
# problem into a stand-alone function we reduce the scope for bugs, and
# this modular approach at the same time makes testing easier.
#
# We take the different pieces of the puzzle we&rsquo;ve developed and
# put them together in the form of a linear program we can solve.
# Recall that the mathematical problem we&rsquo;re trying to solve is
# $$
#     \min_x p'x
# $$
# such that
# $$
#      Ax \geq b
# $$
# If we buy a bag of groceries with quantities given by $x$, the total
# cost of the bag of groceries is the inner product of prices and
# quantities.  Since we&rsquo;ve converted our units above, this gives us a
# vector of prices where quantities are all in 100 g or ml units.
#
# The following code block defines a function
# `solve_subsistence_problem`, which takes as arguments a dataframe
# mapping different foods to nutrients; a series of prices for those
# same foods; a series giving dietary recommended intake (DRI) minimums;
# and a series giving dietary recommended maximums.

# %%
def solve_subsistence_problem(FoodNutrients,Prices,dietmin,dietmax,max_weight=None,tol=1e-6):
    """Solve Stigler's Subsistence Cost Problem.

    Inputs:
       - FoodNutrients : A pd.DataFrame with rows corresponding to foods, columns to nutrients.
       - Prices : A pd.Series of prices for different foods
       - diet_min : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing minimum intakes.
       - diet_max : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing maximum intakes.
       - max_weight : Maximum weight (in hectograms) allowed for diet.
       - tol : Solution values smaller than this in absolute value treated as zeros.
       
    """
    try: 
        p = Prices.apply(lambda x:x.magnitude)
    except AttributeError:  # Maybe not passing in prices with units?
        warnings.warn("Prices have no units.  BE CAREFUL!  We're assuming prices are per hectogram or deciliter!")
        p = Prices

    p = p.dropna()

    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p.index.intersection(FoodNutrients.columns)
    p = p[use]

    # Drop nutritional information for foods we don't know the price of,
    # and replace missing nutrients with zeros.
    Aall = FoodNutrients[p.index].fillna(0)

    # Drop rows of A that we don't have constraints for.
    Amin = Aall.loc[Aall.index.intersection(dietmin.index)]
    Amin = Amin.reindex(dietmin.index,axis=0)
    idx = Amin.index.to_frame()
    idx['type'] = 'min'
    #Amin.index = pd.MultiIndex.from_frame(idx)
    #dietmin.index = Amin.index
    
    Amax = Aall.loc[Aall.index.intersection(dietmax.index)]
    Amax = Amax.reindex(dietmax.index,axis=0)
    idx = Amax.index.to_frame()
    idx['type'] = 'max'
    #Amax.index = pd.MultiIndex.from_frame(idx)
    #dietmax.index = Amax.index

    # Minimum requirements involve multiplying constraint by -1 to make <=.
    A = pd.concat([Amin,
                   -Amax])

    b = pd.concat([dietmin,
                   -dietmax]) # Note sign change for max constraints

    # Make sure order of p, A, b are consistent
    A = A.reindex(p.index,axis=1)
    A = A.reindex(b.index,axis=0)

    if max_weight is not None:
        # Add up weights of foods consumed
        A.loc['Hectograms'] = -1
        b.loc['Hectograms'] = -max_weight
        
    # Now solve problem!  (Note that the linear program solver we'll use assumes
    # "less-than-or-equal" constraints.  We can switch back and forth by
    # multiplying $A$ and $b$ by $-1$.)

    result = lp(p, -A, -b, method='interior-point')

    result.A = A
    result.b = b
    
    if result.success:
        result.diet = pd.Series(result.x,index=p.index)
    else: # No feasible solution?
        warnings.warn(result.message)
        result.diet = pd.Series(result.x,index=p.index)*np.nan  

    return result

# %%
def solution(city,group):
    Prices, FoodNutrients = match(city)
    tol = 1e-6

    result = solve_subsistence_problem(FoodNutrients,Prices,diet_min[group],diet_max[group],tol=tol)

    print("Cost of diet for %s is $%4.2f per day.\n" % (group,result.fun))

    # Put back into nice series
    diet = result.diet

    print("\nDiet (in 100s of grams or milliliters):")
    print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.
    print()

    tab = pd.DataFrame({"Outcome":np.abs(result.A).dot(diet),"Recommendation":np.abs(result.b)})
    print("\nWith the following nutritional outcomes of interest:")
    print(tab)
    print()

    print("\nConstraining nutrients are:")
    excess = tab.diff(axis=1).iloc[:,1]
    print(excess.loc[np.abs(excess) < tol*100].index.tolist())

# %%
def match(city):
    if city == 'San_Francisco':
        return sprouts_price, sprouts_nutrient
    if store == 'Bakersfield':
        return safeway_price, safeway_nutrient

# %%
solution('San_Francisco', 'M 14-18')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 solution('San_Francisco', 'M 14-18')
#
# Cell In[101], line 2, in solution(city, group)
#       1 def solution(city,group):
# ----> 2     Prices, FoodNutrients = match(city)
#       3     tol = 1e-6
#       5     result = solve_subsistence_problem(FoodNutrients,Prices,diet_min[group],diet_max[group],tol=tol)
#
# Cell In[102], line 3, in match(city)
#       1 def match(city):
#       2     if city == 'San_Francisco':
# ----> 3         return sprouts_price, sprouts_nutrient
#       4     if store == 'Bakersfield':
#       5         return safeway_price, safeway_nutrient
#
# NameError: name 'sprouts_price' is not defined

# %%
solution('Bakersfield', 'M 14-18')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 solution('Bakersfield', 'M 14-18')
#
# Cell In[101], line 2, in solution(city, group)
#       1 def solution(city,group):
# ----> 2     Prices, FoodNutrients = match(city)
#       3     tol = 1e-6
#       5     result = solve_subsistence_problem(FoodNutrients,Prices,diet_min[group],diet_max[group],tol=tol)
#
# Cell In[102], line 4, in match(city)
#       2 if city == 'San_Francisco':
#       3     return sprouts_price, sprouts_nutrient
# ----> 4 if store == 'Bakersfield':
#       5     return safeway_price, safeway_nutrient
#
# NameError: name 'store' is not defined
